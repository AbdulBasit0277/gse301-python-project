# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulBasit0277/gse301-python-project/blob/main/student_acad_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##The objectives of this project is to build a system that stores,processes, and analyzes mock academic data for your individual department.

# %%
#part 1: Data collection and storage.
#Task 1.1
student_name = "Abdulbasit"
matric_no = "22/30GR064"
age = 34
cgpa = 4.99
is_active = True
course_reg = ["CPE 341","CPE 331","CPE 321","CPE 311","CPE 381","MEE 361","GSE 301","GNS 301"]
grade = {"CPE 341":"A",
         "CPE 331":"A",
         "CPE 321":"A",
         "CPE 311":"A",
         "CPE 381":"B",
         "MEE 361":"A",
         "GSE 301":"A",
         "GNS 301":"A"}

# %%
#Task 1.2 :Data structure in action
#names of students
student_names = ["Abdulbasit","Toyyib","Abdus-salaam","Malik","Al-mukhtar"]
#Dictionary for each student's profile
student1 = {"name":"Abdulbasit",
            "matric_no":"22/30GR064",
            "age":12,
            "cgpa":4.86,
            "is_active":True,
            "course_reg":["CPE 381","MEE 361","GSE 301","GNS 301"],
            "grade":{"CPE 381":"B",
                     "MEE 361":"A",
                    "GSE 301":"A",
                    "GNS 301":"A"}
                    }

# %%
student2 = {"name":"Toyyib",
            "matric_no":"22/43EF043",
            "age":15,
            "cgpa":4.76,
            "is_active":True,
            "course_reg":["ICH 381","ICH 361","GSE 301","GNS 301"],
            "grade":{"ICH 381":"B",
                     "ICH 361":"A",
                    "GSE 301":"B",
                    "GNS 301":"A"}
                    }

# %%
student3 = {"name":"Abdu-salaam",
            "matric_no":"22/30GR096",
            "age":27,
            "cgpa":4.36,
            "is_active":True,
            "course_reg":["CPE 381","MEE 361","GSE 301","GNS 301"],
            "grade":{"CPE 381":"B",
                     "MEE 361":"A",
                    "GSE 301":"A",
                    "GNS 301":"C"}
                    }

# %%
student4 = {"name":"Malik",
            "matric_no":"22/30GR085",
            "age":18,
            "cgpa":4.01,
            "is_active":True,
            "course_reg":["CPE 381","MEE 361","GSE 301","GNS 301"],
            "grade":{"CPE 381":"C",
                     "MEE 361":"A",
                    "GSE 301":"A",
                    "GNS 301":"B"}
                    }

# %%
student5 = {"name":"Al-mukhtar",
            "matric_no":"22/30GM015",
            "age":19,
            "cgpa":4.66,
            "is_active":True,
            "course_reg":["ELE 381","MEE 361","GSE 301","GNS 301"],
            "grade":{"ELE 381":"B",
                     "MEE 361":"A",
                    "GSE 301":"A",
                    "GNS 301":"B"}
                    }

# %%
#set to store unique courses
unique_courses = {"GSE 301","GNS 301","ICH 381","ICH 361","ELE 382"}

# %%
# tuple for department info
department_info = ("Department of computer Engineering","Faculty of Engineering and Technology",2025)

# %%
#Task 2.1: Conditional statement for grading
#grading using if,elif,else condition
def grade(score):
  if score >= 70 and score <= 100:
    print("A")
  elif score >= 60:
    print("B")
  elif score >= 50:
    print("C")
  elif score >= 45:
    print("D")
  elif score >= 40:
    print("E")
  else:
    print("F")

# %% [markdown]
# Part 2 : DATA PROCESSING AND LOGIC
# Task 2.1 : Conditional statement for grading

# %%
def grade_score(score):
    if score >= 70:
        return "A"
    elif score >= 60:
        return "B"
    elif score >= 50:
        return "C"
    elif score >= 45:
        return "D"
    elif score >= 40:
        return "E"
    else:
        return "F"

mark = int(input("Enter your score: "))
grade = grade_score(mark)

match grade:
    case "A":
        print("Satisfactory")
    case "B":
        print("Very good")
    case "C":
        print("Good")
    case _:
        print("Fail,come again next year")
# Out:
# Enter your score: 23
# Needs improvement

# %% [markdown]
# Task 2.2 : Type conversion and Validation

# %%
try:
   user_age = input("Enter your age: ")
   user_cgpa = input("Enter your CGPA: ")

   age = int(user_age)
   cgpa = float(user_cgpa)
  #Validating age
   if age < 16 or age > 40:
       raise ValueError("Age must be between 16 and 40")

  #Validating CGPA
   if cgpa < 0.0 or cgpa > 5.0:
     raise ValueError("CGPA must be between 0.0 and 5.0")

   print(age)
   print(cgpa)

except ValueError as e:
    print(e)

except Exception:
    print("Something went wrong. Please enter correct values.")
# Out:
# Enter your age: 34
# Enter your CGPA: 9.98
# CGPA must be between 0.0 and 5.0

# %% [markdown]
# # Part : Analysing and reporting

# %%
#Task 3.1
scores = [27, 87, 45, 76, 12, 95, 56, 18, 23, 39]
#arrange the score in descending order using sorted method
sorted_scores = sorted(scores, reverse=True)
#Top 3 scores
top3 = sorted_scores[0:3]

#last 5 using negative indexing
last5 = scores[-5:]

#Every other scores
other_scores = scores[::2]

#printed result
print(top3)
print(last5)
print(other_scores)
# Out:
# [95, 87, 76]
# [95, 56, 18, 23, 39]
# [27, 45, 12, 56, 23]

# %%
#Task 3.2:Set operation
passed_students = {"Abdulbasit", "Toyyib", "Abdulmujeeb", "Favor", "Musa"}
merit_students = {"Toyyib", "Musa", "Sarafa"}

# Students with pass and merit
print(passed_students & merit_students)

#distict students in both
print(passed_students | merit_students)

#students that passed but do not habe merit
print(passed_students - merit_students)
# Out:
# {'Musa', 'Toyyib'}
# {'Musa', 'Abdulmujeeb', 'Toyyib', 'Favor', 'Sarafa', 'Abdulbasit'}
# {'Abdulmujeeb', 'Favor', 'Abdulbasit'}

# %% [markdown]
# #Part 4 : Interactive menu system

# %%
# Task 4.1: Build a console menu
students = ["Abioye","Kamal","Zaynab"]

while True:
    print("WELCOME TO STUDENT MANAGEMENT MENU")
    print("1. View all students")
    print("2. Add new student")
    print("3. Check eligibility for graduation")
    print("4. Find top performance")
    print("5. Exit")

    option = int(input("Select an option (1-5): "))

    match option:
        case 1:
            if not students:
                print("No students available.")
            else:
                print("\nList of Students:")
                for student in students:
                    print(student)

        case 2:
            name = input("Enter student name: ")
            score = float(input("Enter student score: "))
            students.append({"name": name, "score": score})
            print("Student added successfully.")

        case 3:
            if not students:
                print("No students available.")
            else:
                for student in students:
                    if student["score"] >= 50:
                        print(f"{student['name']} is eligible for graduation.")
                    else:
                        print(f"{student['name']} is NOT eligible for graduation.")

        case 4:
            if not students:
                print("No students available.")
            else:
                top_student = max(students, key=lambda x: x["score"])
                print(f"Top Performer: {top_student['name']} with score {top_student['score']}")

        case 5:
            print("Exiting program. Goodbye!")
            break

        case _:
            print("Invalid choice. Please select between 1 and 5.")
# Out:
# WELCOME TO STUDENT MANAGEMENT MENU
# 1. View all students
# 2. Add new student
# 3. Check eligibility for graduation
# 4. Find top performance
# 5. Exit
# Select an option (1-5): 5
# Exiting program. Goodbye!

# %%
#Task 4.2:Eligibility checker
def check_graduation_eligibility(cgpa, outstanding_courses, is_active):
    if cgpa >= 2.5 and outstanding_courses == 0 and is_active:
        return True, "Eligible for graduation: CGPA requirement met, no outstanding courses, and student is active."

    else:
        reasons = []

        if cgpa < 2.5:
            reasons.append("CGPA is below 2.5")

        if outstanding_courses > 0:
            reasons.append("Outstanding courses remaining")

        if not is_active:
            reasons.append("Student is not active")

        return False, "Not eligible for graduation because: " + ", ".join(reasons)

cgpa_status = float(input("Enter your CGPA: "))
outstanding = int(input("Enter the outstanding courses: "))
active = ("Enter True or False: ")
status, message = check_graduation_eligibility(cgpa_status, outstanding, active)
print(status)   # True
print(message)
# Out:
# Enter your CGPA: 1.3
# Enter the outstanding courses: 0
# False
# Not eligible for graduation because: CGPA is below 2.5

# %% [markdown]
# #Part 5":Advanced challenges(Optinal)

# %%
#Task 5.1:Nested Data processing
students_scores = {
    "Ambali": {"GSE 301": 75, "MEE 361": 82, "CPE 321": 78},
    "Tunde": {"GSE 302": 68, "MEE 361": 74, "CPE 321": 80},
    "MUwafiq": {"GSE 301": 85, "MEE 361": 90, "CPE 321": 88},
    "Abdullah": {"GSE 301": 72, "MEE 361": 69, "CPE 321": 75}
}

# Calculate average score for each student
averages = {}

for student, courses in students_scores.items():
    total = sum(courses.values())
    average = total / len(courses)
    averages[student] = average

# Display averages
print("Average scores:")
for student, avg in averages.items():
    print(f"{student}: {avg:.2f}")

# Find the first student who scored above 70 in all courses
first_student_above_70 = None

for student, courses in students_scores.items():
    if all(score > 70 for score in courses.values()):
        first_student_above_70 = student
        break

# Display result
if first_student_above_70:
    print(f"\nFirst student who scored above 70 in all courses: {first_student_above_70}")
else:
    print("\nNo student scored above 70 in all courses.")
# Out:
# Average scores:
# Amina: 78.33
# Tunde: 74.00
# Sadiq: 87.67
# Zainab: 72.00
#
# First student who scored above 70 in all courses: Amina
